# %%
import arff

from scipy import sparse
decoder = arff.ArffDecoder()
d = decoder.decode(open('rcv1subset1-train.arff', 'r'), encode_nominal=True, return_type=arff.COO)
data = d['data'][0]
row = d['data'][1]
col = d['data'][2]
matrix = sparse.coo_matrix((data, (row, col)), shape=(max(row)+1, max(col)+1))

# %%
import numpy as np
from scipy.stats import chi2_contingency
matrix.get_shape() # (3000, 47337). Last attribute Att47236 occurs in index 47235
# chi squared
chi2 = np.zeros((matrix.get_shape()[1],101)) # num_features x num_labels

# %%
for i in range(26270,chi2.shape[0]):
  
  print(i)
  for j in range(chi2.shape[1]):
    feature_occur = matrix.getcol(i).A
    feature_occur = 1*(feature_occur>0)
    label_occur = matrix.getcol(j+47236).A
    a = np.count_nonzero(feature_occur*label_occur) # num articles with both features and label
    b = np.count_nonzero(feature_occur*(1-label_occur)) # feature but not category
    c = np.count_nonzero((1-feature_occur)*label_occur)
    d = np.count_nonzero((1-feature_occur)*(1-label_occur))
    
    contingency = np.array([[a, b], [c, d]])
    if (np.sum(contingency, 0) > 0).all() and (np.sum(contingency, 1) > 0).all():
        chi2[i,j], _, _, _ = chi2_contingency(contingency)
    else:
        chi2[i,j] = 0
# Out:
# 26270
# 26271
# 26272
# 26273
# 26274
# 26275
# 26276
# 26277
# 26278
# 26279
# 26280
# 26281
# 26282
# 26283
# 26284
# 26285
# 26286
# 26287
# 26288
# 26289
# 26290
# 26291
# 26292
# 26293
# 26294
# 26295
# 26296
# 26297
# 26298
# 26299
# 26300
# 26301
# 26302
# 26303
# 26304
# 26305
# 26306
# 26307
# 26308
# 26309
# 26310
# 26311
# 26312
# 26313
# 26314
# 26315
# 26316
# 26317
# 26318
# 26319
# 26320
# 26321
# 26322
# 26323
# 26324
# 26325
# 26326
# 26327
# 26328
# 26329
# 26330
# 26331
# 26332
# 26333
# 26334
# 26335
# 26336
# 26337
# 26338
# 26339
# 26340
# 26341
# 26342
# 26343
# 26344
# 26345
# 26346
# 26347
# 26348
# 26349
# 26350
# 26351
# 26352
# 26353
# 26354
# 26355
# 26356
# 26357
# 26358
# 26359
# 26360
# 26361
# 26362
# 26363
# 26364
# 26365
# 26366
# 26367
# 26368
# 26369
# 26370
# 26371
# 26372
# 26373
# 26374
# 26375
# 26376
# 26377
# 26378
# 26379
# 26380
# 26381
# 26382
# 26383
# 26384
# 26385
# 26386
# 26387
# 26388
# 26389
# 26390
# 26391
# 26392
# 26393
# 26394
# ...

# %%
import numpy as np
np.save('chi2_6.npy', chi2)

# %%
import matplotlib.pyplot as plt
plt.matshow(chi2, aspect='auto')

# %%
features_total_chi = np.sum(chi2,1)
print(np.argsort(features_total_chi)[::-1])
print(np.sort(features_total_chi)[::-1])
# Out:
# [11163  6880 12178 ... 31552 31551     0]
# [11083.00667802 11083.00667802 11083.00667802 ...     0.
#      0.             0.        ]

# %%
import matplotlib.pyplot as plt
temp=chi2.copy()
temp = temp[0:10000]
plt.figure(figsize=(16,120))
#plt.matshow(chi2[0:6000],aspect='auto',vmax=50),plt.colorbar()
plt.spy(temp>6,aspect='auto')
#plt.savefig('spy.png',dpi=300)
#plt.spy(temp<0.01,aspect='auto')

# %%
significant = temp>6 # the features-label matrix, with significant dependencies being True
order_by_label = np.argsort(np.sum(significant,0))[::-1]
order_by_features = np.argsort(np.sum(significant,1))[::-1]

significant = significant[:,order_by_label]
significant = significant[order_by_features,:]
chi2_visualize = temp.copy()
chi2_visualize = chi2_visualize[:,order_by_label]
chi2_visualize = chi2_visualize[order_by_features,:]
plt.figure(figsize=(16,120))
plt.matshow(chi2_visualize,aspect='auto',vmax=50),plt.colorbar()
plt.savefig('features_label_chi_dependency.png',dpi=300)
#plt.spy(significant,aspect='auto')
print(order_by_label)
print(np.sort(np.sum(significant,0)))
#print(np.argsort(np.sum(matrix[:,47236:],0)))
#print(np.sort(np.sum(matrix[:,47236:],0)))
# Out:
# [ 50  80  42  49  57  66  69  77  43  28  41  81   8  88  61  36  20  85
#   65  12  39  25  67  48  40  13  92  62  63  47  52  26  75  56  82  24
#   54  86  38  68  58  84  90  17  16  37  19  23  78  29  91  64  55  31
#   30   3  72  76   1  32 100  74  34  11   6  89  60  45  46  35   0  27
#   79  51  18  53  10  70  83  98  33  73  87   4  59  99  44  71  94  93
#    5   2  95  14  97  15  21   7   9  96  22]
# [  42   44   50   54   60   66   72   72   83   84  100  100  102  129
#   131  132  143  168  176  211  224  231  284  500 1241 1249 1254 1257
#  1259 1262 1263 1290 1304 1306 1330 1418 1717 1737 1752 1752 1756 1761
#  1773 1775 1788 1987 1989 1989 1997 2039 2178 2181 2195 2290 2296 2296
#  2385 2397 2402 2404 2410 2412 2458 2473 2501 2508 2519 2558 2574 2577
#  2656 2677 2683 2690 2693 2725 2726 2726 2735 2774 2775 2775 2783 2789
#  2819 2819 2828 2885 2886 2962 3037 3038 3041 3149 3149 3149 3149 3149
#  3149 3149 3149]
